# %% [markdown]
# # JAX Basics

# %%
import numpy as np
import jax
import jax.numpy as jnp
from jax import random, jit, grad, vmap

key = random.PRNGKey(0)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %% [markdown]
# # Jax as GPU backed NumPy

# %%
x_gpu = random.normal(key, (3000,3000))
print(type(x_gpu))
# Out:
# <class 'jaxlib.xla_extension.DeviceArray'>

# %%
# %timeit -n 1 -r 1 jnp.dot(x_gpu, x_gpu.T).block_until_ready()
# Out:
# 175 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
x_cpu = np.array(x_gpu)

# %timeit -n 1 -r 1 np.dot(x_cpu,x_cpu.T)
# Out:
# 127 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# # Automatic differentiation

# %%
def sum_of_squares(x):
    return jnp.sum(x**2)

sum_of_squares_dx = grad(sum_of_squares)

# %% [markdown]
# $$
# f = \sum_{i \in X} i^2 = X^t X\\
# \nabla f = 2 X
# $$

# %%
x = jnp.asarray([1., 2., 3., 4])

print(sum_of_squares(x))

print(sum_of_squares_dx(x))
# Out:
# 30.0
# [2. 4. 6. 8.]

# %%
def f(x):
    for i in range(8):
        x = x + x * i + 3
    return x

# %%
grad(f)(290.)
# Out:
# DeviceArray(40320., dtype=float32)

# %% [markdown]
# # Using jit() to speed up functions

# %%
def mse(x, y):
    return jnp.mean((x - y) ** 2)

jit_mse = jit(mse)

# %%
x = random.normal(key, (100000,))

# %timeit mse(x, x).block_until_ready()
# Out:
# 415 µs ± 18 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit jit_mse(x, x).block_until_ready()
# Out:
# 60.3 µs ± 1.5 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# # Vectorization

# %%
def norm(vect):
    return jnp.sqrt(jnp.sum(vect ** 2))

def naive_batched_norm(x): 
    return jnp.stack([norm(vect) for vect in x])

vmap_norm = vmap(norm)

# %%
matrix = random.normal(key, (100, 100))

# %%
# %timeit naive_batched_norm(matrix).block_until_ready()
# Out:
# 39.8 ms ± 1.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit vmap_norm(matrix).block_until_ready()
# Out:
# 930 µs ± 13.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
jit_vmap_norm = jit(vmap_norm)
# %timeit jit_vmap_norm(matrix).block_until_ready()
# Out:
# 22.2 µs ± 2.45 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
 naive_batched_norm(matrix)
# Out:
# DeviceArray([ 9.424122 ,  9.48725  ,  9.005592 ,  9.376043 ,  8.738633 ,
#               9.67595  , 10.202312 ,  9.295728 , 10.043758 , 11.205047 ,
#              10.043984 ,  9.783223 ,  9.775057 ,  9.872046 , 11.055422 ,
#              11.051067 ,  9.390705 , 10.003488 , 10.729829 ,  9.728503 ,
#              10.564091 ,  9.68822  ,  9.859245 , 10.632973 , 10.256151 ,
#              11.143114 , 11.010348 ,  9.898047 , 10.956767 , 10.345362 ,
#               9.701541 , 10.382492 ,  9.457232 ,  9.91471  , 11.022385 ,
#              10.168085 ,  8.986782 , 10.513088 , 10.427667 ,  9.694277 ,
#              10.646457 , 11.129786 , 10.154379 ,  9.784558 ,  9.633135 ,
#              10.000055 ,  9.502357 , 10.485467 , 10.889698 , 10.201964 ,
#               9.463949 , 10.868552 ,  9.912413 , 10.541245 , 10.432263 ,
#              10.040994 ,  8.693418 ,  9.699597 ,  9.186164 ,  9.984744 ,
#              11.57897  , 11.4064045,  9.4746065, 10.667576 ,  9.949682 ,
#              11.235698 ,  9.689346 , 10.480486 , 10.788445 ,  9.844126 ,
#               9.943344 , 10.641448 , 10.020704 ,  9.614654 , 10.972419 ,
#              10.134055 ,  8.983256 ,  8.947499 , 10.048028 , 10.073077 ,
#              11.398746 ,  8.685024 , 10.386158 , 10.05509  , 10.19776  ,
#              10.957117 ,  8.945872 , 10.4901905, 10.781119 ,  9.167804 ,
#              10.090993 , 11.523735 ,  9.915879 ,  8.730988 , 10.433362 ,
#               9.65711  ,  9.766672 ,  9.945658 ,  9.335738 , 10.083751 ],            dtype=float32)

# %%
vmap_norm(matrix)
# Out:
# DeviceArray([ 9.424122 ,  9.48725  ,  9.005592 ,  9.376043 ,  8.738633 ,
#               9.67595  , 10.202313 ,  9.295728 , 10.043758 , 11.205046 ,
#              10.043985 ,  9.783223 ,  9.775057 ,  9.872046 , 11.055422 ,
#              11.051067 ,  9.390705 , 10.003488 , 10.729829 ,  9.728503 ,
#              10.564091 ,  9.68822  ,  9.859245 , 10.632973 , 10.25615  ,
#              11.143114 , 11.010349 ,  9.898047 , 10.956766 , 10.345362 ,
#               9.701541 , 10.382493 ,  9.457232 ,  9.91471  , 11.022385 ,
#              10.168085 ,  8.986781 , 10.513088 , 10.427667 ,  9.694277 ,
#              10.646457 , 11.129786 , 10.154379 ,  9.784558 ,  9.633134 ,
#              10.000055 ,  9.5023575, 10.485467 , 10.889699 , 10.201964 ,
#               9.463949 , 10.868552 ,  9.912413 , 10.541246 , 10.432263 ,
#              10.040994 ,  8.693418 ,  9.699597 ,  9.186165 ,  9.984744 ,
#              11.57897  , 11.406404 ,  9.4746065, 10.667576 ,  9.949682 ,
#              11.235698 ,  9.689347 , 10.480486 , 10.788445 ,  9.844126 ,
#               9.943344 , 10.641447 , 10.020703 ,  9.614654 , 10.972419 ,
#              10.134055 ,  8.983256 ,  8.947499 , 10.048027 , 10.073077 ,
#              11.398746 ,  8.685024 , 10.386158 , 10.05509  , 10.19776  ,
#              10.957117 ,  8.945872 , 10.4901905, 10.781119 ,  9.167804 ,
#              10.090992 , 11.523736 ,  9.915878 ,  8.730988 , 10.433362 ,
#               9.657109 ,  9.766672 ,  9.945658 ,  9.335738 , 10.083751 ],            dtype=float32)

# %%
jit_vmap_norm(matrix)
# Out:
# DeviceArray([ 9.424122 ,  9.48725  ,  9.005592 ,  9.376043 ,  8.738633 ,
#               9.67595  , 10.202313 ,  9.295728 , 10.043758 , 11.205046 ,
#              10.043985 ,  9.783223 ,  9.775057 ,  9.872046 , 11.055422 ,
#              11.051067 ,  9.390705 , 10.003488 , 10.729829 ,  9.728503 ,
#              10.564091 ,  9.68822  ,  9.859245 , 10.632973 , 10.25615  ,
#              11.143114 , 11.010349 ,  9.898047 , 10.956766 , 10.345362 ,
#               9.701541 , 10.382493 ,  9.457232 ,  9.91471  , 11.022385 ,
#              10.168085 ,  8.986781 , 10.513088 , 10.427667 ,  9.694277 ,
#              10.646457 , 11.129786 , 10.154379 ,  9.784558 ,  9.633134 ,
#              10.000055 ,  9.5023575, 10.485467 , 10.889699 , 10.201964 ,
#               9.463949 , 10.868552 ,  9.912413 , 10.541246 , 10.432263 ,
#              10.040994 ,  8.693418 ,  9.699597 ,  9.186165 ,  9.984744 ,
#              11.57897  , 11.406404 ,  9.4746065, 10.667576 ,  9.949682 ,
#              11.235698 ,  9.689347 , 10.480486 , 10.788445 ,  9.844126 ,
#               9.943344 , 10.641447 , 10.020703 ,  9.614654 , 10.972419 ,
#              10.134055 ,  8.983256 ,  8.947499 , 10.048027 , 10.073077 ,
#              11.398746 ,  8.685024 , 10.386158 , 10.05509  , 10.19776  ,
#              10.957117 ,  8.945872 , 10.4901905, 10.781119 ,  9.167804 ,
#              10.090992 , 11.523736 ,  9.915878 ,  8.730988 , 10.433362 ,
#               9.657109 ,  9.766672 ,  9.945658 ,  9.335738 , 10.083751 ],            dtype=float32)

# %% [markdown]
# # How does it work ?

# %%
jax.make_jaxpr(norm)(x)
# Out:
# { lambda  ; a.
#   let b = integer_pow[ y=2 ] a
#       c = reduce_sum[ axes=(0,) ] b
#       d = sqrt c
#   in (d,) }

# %%
jax.make_jaxpr(naive_batched_norm)(matrix)
# Out:
# { lambda  ; a.
#   let b = slice[ limit_indices=(1, 100)
#                  start_indices=(0, 0)
#                  strides=(1, 1) ] a
#       c = squeeze[ dimensions=(0,) ] b
#       d = slice[ limit_indices=(2, 100)
#                  start_indices=(1, 0)
#                  strides=(1, 1) ] a
#       e = squeeze[ dimensions=(0,) ] d
#       f = slice[ limit_indices=(3, 100)
#                  start_indices=(2, 0)
#                  strides=(1, 1) ] a
#       g = squeeze[ dimensions=(0,) ] f
#       h = slice[ limit_indices=(4, 100)
#                  start_indices=(3, 0)
#                  strides=(1, 1) ] a
#       i = squeeze[ dimensions=(0,) ] h
#       j = slice[ limit_indices=(5, 100)
#                  start_indices=(4, 0)
#                  strides=(1, 1) ] a
#       k = squeeze[ dimensions=(0,) ] j
#       l = slice[ limit_indices=(6, 100)
#                  start_indices=(5, 0)
#                  strides=(1, 1) ] a
#       m = squeeze[ dimensions=(0,) ] l
#       n = slice[ limit_indices=(7, 100)
#                  start_indices=(6, 0)
#                  strides=(1, 1) ] a
#       o = squeeze[ dimensions=(0,) ] n
#       p = slice[ limit_indices=(8, 100)
#                  start_indices=(7, 0)
#                  strides=(1, 1) ] a
#       q = squeeze[ dimensions=(0,) ] p
#       r = slice[ limit_indices=(9, 100)
#                  start_indices=(8, 0)
#                  strides=(1, 1) ] a
#       s = squeeze[ dimensions=(0,) ] r
#       t = slice[ limit_indices=(10, 100)
#                  start_indices=(9, 0)
#                  strides=(1, 1) ] a
#       u = squeeze[ dimensions=(0,) ] t
#       v = slice[ limit_indices=(11, 100)
#                  start_indices=(10, 0)
#                  strides=(1, 1) ] a
#       w = squeeze[ dimensions=(0,) ] v
#       x = slice[ limit_indices=(12, 100)
#                  start_indices=(11, 0)
#                  strides=(1, 1) ] a
#       y = squeeze[ dimensions=(0,) ] x
#       z = slice[ limit_indices=(13, 100)
#                  start_indices=(12, 0)
#                  strides=(1, 1) ] a
#       ba = squeeze[ dimensions=(0,) ] z
#       bb = slice[ limit_indices=(14, 100)
#                   start_indices=(13, 0)
#                   strides=(1, 1) ] a
#       bc = squeeze[ dimensions=(0,) ] bb
#       bd = slice[ limit_indices=(15, 100)
#                   start_indices=(14, 0)
#                   strides=(1, 1) ] a
#       be = squeeze[ dimensions=(0,) ] bd
#       bf = slice[ limit_indices=(16, 100)
#                   start_indices=(15, 0)
#                   strides=(1, 1) ] a
#       bg = squeeze[ dimensions=(0,) ] bf
#       bh = slice[ limit_indices=(17, 100)
#                   start_indices=(16, 0)
#                   strides=(1, 1) ] a
#       bi = squeeze[ dimensions=(0,) ] bh
#       bj = slice[ limit_indices=(18, 100)
#                   start_indices=(17, 0)
#                   strides=(1, 1) ] a
#       bk = squeeze[ dimensions=(0,) ] bj
#       bl = slice[ limit_indices=(19, 100)
#                   start_indices=(18, 0)
#                   strides=(1, 1) ] a
#       bm = squeeze[ dimensions=(0,) ] bl
#       bn = slice[ limit_indices=(20, 100)
#                   start_indices=(19, 0)
#                   strides=(1, 1) ] a
#       bo = squeeze[ dimensions=(0,) ] bn
#       bp = slice[ limit_indices=(21, 100)
#                   start_indices=(20, 0)
#                   strides=(1, 1) ] a
#       bq = squeeze[ dimensions=(0,) ] bp
#       br = slice[ limit_indices=(22, 100)
#                   start_indices=(21, 0)
#                   strides=(1, 1) ] a
#       bs = squeeze[ dimensions=(0,) ] br
#       bt = slice[ limit_indices=(23, 100)
#                   start_indices=(22, 0)
#                   strides=(1, 1) ] a
#       bu = squeeze[ dimensions=(0,) ] bt
#       bv = slice[ limit_indices=(24, 100)
#                   start_indices=(23, 0)
#                   strides=(1, 1) ] a
#       bw = squeeze[ dimensions=(0,) ] bv
#       bx = slice[ limit_indices=(25, 100)
#                   start_indices=(24, 0)
#                   strides=(1, 1) ] a
#       by = squeeze[ dimensions=(0,) ] bx
#       bz = slice[ limit_indices=(26, 100)
#                   start_indices=(25, 0)
#                   strides=(1, 1) ] a
#       ca = squeeze[ dimensions=(0,) ] bz
#       cb = slice[ limit_indices=(27, 100)
#                   start_indices=(26, 0)
#                   strides=(1, 1) ] a
#       cc = squeeze[ dimensions=(0,) ] cb
#       cd = slice[ limit_indices=(28, 100)
#                   start_indices=(27, 0)
#                   strides=(1, 1) ] a
#       ce = squeeze[ dimensions=(0,) ] cd
#       cf = slice[ limit_indices=(29, 100)
#                   start_indices=(28, 0)
#                   strides=(1, 1) ] a
#       cg = squeeze[ dimensions=(0,) ] cf
#       ch = slice[ limit_indices=(30, 100)
#                   start_indices=(29, 0)
#                   strides=(1, 1) ] a
#       ci = squeeze[ dimensions=(0,) ] ch
#       cj = slice[ limit_indices=(31, 100)
#                   start_indices=(30, 0)
#                   strides=(1, 1) ] a
#       ck = squeeze[ dimensions=(0,) ] cj
#       cl = slice[ limit_indices=(32, 100)
#                   start_indices=(31, 0)
#                   strides=(1, 1) ] a
#       cm = squeeze[ dimensions=(0,) ] cl
#       cn = slice[ limit_indices=(33, 100)
#                   start_indices=(32, 0)
#                   strides=(1, 1) ] a
#       co = squeeze[ dimensions=(0,) ] cn
#       cp = slice[ limit_indices=(34, 100)
#                   start_indices=(33, 0)
#                   strides=(1, 1) ] a
#       cq = squeeze[ dimensions=(0,) ] cp
#       cr = slice[ limit_indices=(35, 100)
#                   start_indices=(34, 0)
#                   strides=(1, 1) ] a
#       cs = squeeze[ dimensions=(0,) ] cr
#       ct = slice[ limit_indices=(36, 100)
#                   start_indices=(35, 0)
#                   strides=(1, 1) ] a
#       cu = squeeze[ dimensions=(0,) ] ct
#       cv = slice[ limit_indices=(37, 100)
#                   start_indices=(36, 0)
#                   strides=(1, 1) ] a
#       cw = squeeze[ dimensions=(0,) ] cv
#       cx = slice[ limit_indices=(38, 100)
#                   start_indices=(37, 0)
#                   strides=(1, 1) ] a
#       cy = squeeze[ dimensions=(0,) ] cx
#       cz = slice[ limit_indices=(39, 100)
#                   start_indices=(38, 0)
#                   strides=(1, 1) ] a
#       da = squeeze[ dimensions=(0,) ] cz
#       db = slice[ limit_indices=(40, 100)
#                   start_indices=(39, 0)
#                   strides=(1, 1) ] a
#       dc = squeeze[ dimensions=(0,) ] db
#       dd = slice[ limit_indices=(41, 100)
#                   start_indices=(40, 0)
#                   strides=(1, 1) ] a
#       de = squeeze[ dimensions=(0,) ] dd
#       df = slice[ limit_indices=(42, 100)
#                   start_indices=(41, 0)
#                   strides=(1, 1) ] a
#       dg = squeeze[ dimensions=(0,) ] df
#       dh = slice[ limit_indices=(43, 100)
#                   start_indices=(42, 0)
#                   strides=(1, 1) ] a
#       di = squeeze[ dimensions=(0,) ] dh
#       dj = slice[ limit_indices=(44, 100)
#                   start_indices=(43, 0)
#                   strides=(1, 1) ] a
#       dk = squeeze[ dimensions=(0,) ] dj
#       dl = slice[ limit_indices=(45, 100)
#                   start_indices=(44, 0)
#                   strides=(1, 1) ] a
#       dm = squeeze[ dimensions=(0,) ] dl
#       dn = slice[ limit_indices=(46, 100)
#                   start_indices=(45, 0)
#                   strides=(1, 1) ] a
#       do = squeeze[ dimensions=(0,) ] dn
#       dp = slice[ limit_indices=(47, 100)
#                   start_indices=(46, 0)
#                   strides=(1, 1) ] a
#       dq = squeeze[ dimensions=(0,) ] dp
#       dr = slice[ limit_indices=(48, 100)
#                   start_indices=(47, 0)
#                   strides=(1, 1) ] a
#       ds = squeeze[ dimensions=(0,) ] dr
#       dt = slice[ limit_indices=(49, 100)
#                   start_indices=(48, 0)
#                   strides=(1, 1) ] a
#       du = squeeze[ dimensions=(0,) ] dt
#       dv = slice[ limit_indices=(50, 100)
#                   start_indices=(49, 0)
#                   strides=(1, 1) ] a
#       dw = squeeze[ dimensions=(0,) ] dv
#       dx = slice[ limit_indices=(51, 100)
#                   start_indices=(50, 0)
#                   strides=(1, 1) ] a
#       dy = squeeze[ dimensions=(0,) ] dx
#       dz = slice[ limit_indices=(52, 100)
#                   start_indices=(51, 0)
#                   strides=(1, 1) ] a
#       ea = squeeze[ dimensions=(0,) ] dz
#       eb = slice[ limit_indices=(53, 100)
#                   start_indices=(52, 0)
#                   strides=(1, 1) ] a
#       ec = squeeze[ dimensions=(0,) ] eb
#       ed = slice[ limit_indices=(54, 100)
#                   start_indices=(53, 0)
#                   strides=(1, 1) ] a
#       ee = squeeze[ dimensions=(0,) ] ed
#       ef = slice[ limit_indices=(55, 100)
#                   start_indices=(54, 0)
#                   strides=(1, 1) ] a
#       eg = squeeze[ dimensions=(0,) ] ef
#       eh = slice[ limit_indices=(56, 100)
#                   start_indices=(55, 0)
#                   strides=(1, 1) ] a
#       ei = squeeze[ dimensions=(0,) ] eh
#       ej = slice[ limit_indices=(57, 100)
#                   start_indices=(56, 0)
#                   strides=(1, 1) ] a
#       ek = squeeze[ dimensions=(0,) ] ej
#       el = slice[ limit_indices=(58, 100)
#                   start_indices=(57, 0)
#                   strides=(1, 1) ] a
#       em = squeeze[ dimensions=(0,) ] el
#       en = slice[ limit_indices=(59, 100)
#                   start_indices=(58, 0)
#                   strides=(1, 1) ] a
#       eo = squeeze[ dimensions=(0,) ] en
#       ep = slice[ limit_indices=(60, 100)
#                   start_indices=(59, 0)
#                   strides=(1, 1) ] a
#       eq = squeeze[ dimensions=(0,) ] ep
#       er = slice[ limit_indices=(61, 100)
#                   start_indices=(60, 0)
#                   strides=(1, 1) ] a
#       es = squeeze[ dimensions=(0,) ] er
#       et = slice[ limit_indices=(62, 100)
#                   start_indices=(61, 0)
#                   strides=(1, 1) ] a
#       eu = squeeze[ dimensions=(0,) ] et
#       ev = slice[ limit_indices=(63, 100)
#                   start_indices=(62, 0)
#                   strides=(1, 1) ] a
#       ew = squeeze[ dimensions=(0,) ] ev
#       ex = slice[ limit_indices=(64, 100)
#                   start_indices=(63, 0)
#                   strides=(1, 1) ] a
#       ey = squeeze[ dimensions=(0,) ] ex
#       ez = slice[ limit_indices=(65, 100)
#                   start_indices=(64, 0)
#                   strides=(1, 1) ] a
#       fa = squeeze[ dimensions=(0,) ] ez
#       fb = slice[ limit_indices=(66, 100)
#                   start_indices=(65, 0)
#                   strides=(1, 1) ] a
#       fc = squeeze[ dimensions=(0,) ] fb
#       fd = slice[ limit_indices=(67, 100)
#                   start_indices=(66, 0)
#                   strides=(1, 1) ] a
#       fe = squeeze[ dimensions=(0,) ] fd
#       ff = slice[ limit_indices=(68, 100)
#                   start_indices=(67, 0)
#                   strides=(1, 1) ] a
#       fg = squeeze[ dimensions=(0,) ] ff
#       fh = slice[ limit_indices=(69, 100)
#                   start_indices=(68, 0)
#                   strides=(1, 1) ] a
#       fi = squeeze[ dimensions=(0,) ] fh
#       fj = slice[ limit_indices=(70, 100)
#                   start_indices=(69, 0)
#                   strides=(1, 1) ] a
#       fk = squeeze[ dimensions=(0,) ] fj
#       fl = slice[ limit_indices=(71, 100)
#                   start_indices=(70, 0)
#                   strides=(1, 1) ] a
#       fm = squeeze[ dimensions=(0,) ] fl
#       fn = slice[ limit_indices=(72, 100)
#                   start_indices=(71, 0)
#                   strides=(1, 1) ] a
#       fo = squeeze[ dimensions=(0,) ] fn
#       fp = slice[ limit_indices=(73, 100)
#                   start_indices=(72, 0)
#                   strides=(1, 1) ] a
#       fq = squeeze[ dimensions=(0,) ] fp
#       fr = slice[ limit_indices=(74, 100)
#                   start_indices=(73, 0)
#                   strides=(1, 1) ] a
#       fs = squeeze[ dimensions=(0,) ] fr
#       ft = slice[ limit_indices=(75, 100)
#                   start_indices=(74, 0)
#                   strides=(1, 1) ] a
#       fu = squeeze[ dimensions=(0,) ] ft
#       fv = slice[ limit_indices=(76, 100)
#                   start_indices=(75, 0)
#                   strides=(1, 1) ] a
#       fw = squeeze[ dimensions=(0,) ] fv
#       fx = slice[ limit_indices=(77, 100)
#                   start_indices=(76, 0)
#                   strides=(1, 1) ] a
#       fy = squeeze[ dimensions=(0,) ] fx
#       fz = slice[ limit_indices=(78, 100)
#                   start_indices=(77, 0)
#                   strides=(1, 1) ] a
#       ga = squeeze[ dimensions=(0,) ] fz
#       gb = slice[ limit_indices=(79, 100)
#                   start_indices=(78, 0)
#                   strides=(1, 1) ] a
#       gc = squeeze[ dimensions=(0,) ] gb
#       gd = slice[ limit_indices=(80, 100)
#                   start_indices=(79, 0)
#                   strides=(1, 1) ] a
#       ge = squeeze[ dimensions=(0,) ] gd
#       gf = slice[ limit_indices=(81, 100)
#                   start_indices=(80, 0)
#                   strides=(1, 1) ] a
#       gg = squeeze[ dimensions=(0,) ] gf
#       gh = slice[ limit_indices=(82, 100)
#                   start_indices=(81, 0)
#                   strides=(1, 1) ] a
#       gi = squeeze[ dimensions=(0,) ] gh
#       gj = slice[ limit_indices=(83, 100)
#                   start_indices=(82, 0)
#                   strides=(1, 1) ] a
#       gk = squeeze[ dimensions=(0,) ] gj
#       gl = slice[ limit_indices=(84, 100)
#                   start_indices=(83, 0)
#                   strides=(1, 1) ] a
#       gm = squeeze[ dimensions=(0,) ] gl
#       gn = slice[ limit_indices=(85, 100)
#                   start_indices=(84, 0)
#                   strides=(1, 1) ] a
#       go = squeeze[ dimensions=(0,) ] gn
#       gp = slice[ limit_indices=(86, 100)
#                   start_indices=(85, 0)
#                   strides=(1, 1) ] a
#       gq = squeeze[ dimensions=(0,) ] gp
#       gr = slice[ limit_indices=(87, 100)
#                   start_indices=(86, 0)
#                   strides=(1, 1) ] a
#       gs = squeeze[ dimensions=(0,) ] gr
#       gt = slice[ limit_indices=(88, 100)
#                   start_indices=(87, 0)
#                   strides=(1, 1) ] a
#       gu = squeeze[ dimensions=(0,) ] gt
#       gv = slice[ limit_indices=(89, 100)
#                   start_indices=(88, 0)
#                   strides=(1, 1) ] a
#       gw = squeeze[ dimensions=(0,) ] gv
#       gx = slice[ limit_indices=(90, 100)
#                   start_indices=(89, 0)
#                   strides=(1, 1) ] a
#       gy = squeeze[ dimensions=(0,) ] gx
#       gz = slice[ limit_indices=(91, 100)
#                   start_indices=(90, 0)
#                   strides=(1, 1) ] a
#       ha = squeeze[ dimensions=(0,) ] gz
#       hb = slice[ limit_indices=(92, 100)
#                   start_indices=(91, 0)
#                   strides=(1, 1) ] a
#       hc = squeeze[ dimensions=(0,) ] hb
#       hd = slice[ limit_indices=(93, 100)
#                   start_indices=(92, 0)
#                   strides=(1, 1) ] a
#       he = squeeze[ dimensions=(0,) ] hd
#       hf = slice[ limit_indices=(94, 100)
#                   start_indices=(93, 0)
#                   strides=(1, 1) ] a
#       hg = squeeze[ dimensions=(0,) ] hf
#       hh = slice[ limit_indices=(95, 100)
#                   start_indices=(94, 0)
#                   strides=(1, 1) ] a
#       hi = squeeze[ dimensions=(0,) ] hh
#       hj = slice[ limit_indices=(96, 100)
#                   start_indices=(95, 0)
#                   strides=(1, 1) ] a
#       hk = squeeze[ dimensions=(0,) ] hj
#       hl = slice[ limit_indices=(97, 100)
#                   start_indices=(96, 0)
#                   strides=(1, 1) ] a
#       hm = squeeze[ dimensions=(0,) ] hl
#       hn = slice[ limit_indices=(98, 100)
#                   start_indices=(97, 0)
#                   strides=(1, 1) ] a
#       ho = squeeze[ dimensions=(0,) ] hn
#       hp = slice[ limit_indices=(99, 100)
#                   start_indices=(98, 0)
#                   strides=(1, 1) ] a
#       hq = squeeze[ dimensions=(0,) ] hp
#       hr = slice[ limit_indices=(100, 100)
#                   start_indices=(99, 0)
#                   strides=(1, 1) ] a
#       hs = squeeze[ dimensions=(0,) ] hr
#       ht = integer_pow[ y=2 ] c
#       hu = reduce_sum[ axes=(0,) ] ht
#       hv = sqrt hu
#       hw = integer_pow[ y=2 ] e
#       hx = reduce_sum[ axes=(0,) ] hw
#       hy = sqrt hx
#       hz = integer_pow[ y=2 ] g
#       ia = reduce_sum[ axes=(0,) ] hz
#       ib = sqrt ia
#       ic = integer_pow[ y=2 ] i
#       id = reduce_sum[ axes=(0,) ] ic
#       ie = sqrt id
#       if = integer_pow[ y=2 ] k
#       ig = reduce_sum[ axes=(0,) ] if
#       ih = sqrt ig
#       ii = integer_pow[ y=2 ] m
#       ij = reduce_sum[ axes=(0,) ] ii
#       ik = sqrt ij
#       il = integer_pow[ y=2 ] o
#       im = reduce_sum[ axes=(0,) ] il
#       in = sqrt im
#       io = integer_pow[ y=2 ] q
#       ip = reduce_sum[ axes=(0,) ] io
#       iq = sqrt ip
#       ir = integer_pow[ y=2 ] s
#       is = reduce_sum[ axes=(0,) ] ir
#       it = sqrt is
#       iu = integer_pow[ y=2 ] u
#       iv = reduce_sum[ axes=(0,) ] iu
#       iw = sqrt iv
#       ix = integer_pow[ y=2 ] w
#       iy = reduce_sum[ axes=(0,) ] ix
#       iz = sqrt iy
#       ja = integer_pow[ y=2 ] y
#       jb = reduce_sum[ axes=(0,) ] ja
#       jc = sqrt jb
#       jd = integer_pow[ y=2 ] ba
#       je = reduce_sum[ axes=(0,) ] jd
#       jf = sqrt je
#       jg = integer_pow[ y=2 ] bc
#       jh = reduce_sum[ axes=(0,) ] jg
#       ji = sqrt jh
#       jj = integer_pow[ y=2 ] be
#       jk = reduce_sum[ axes=(0,) ] jj
#       jl = sqrt jk
#       jm = integer_pow[ y=2 ] bg
#       jn = reduce_sum[ axes=(0,) ] jm
#       jo = sqrt jn
#       jp = integer_pow[ y=2 ] bi
#       jq = reduce_sum[ axes=(0,) ] jp
#       jr = sqrt jq
#       js = integer_pow[ y=2 ] bk
#       jt = reduce_sum[ axes=(0,) ] js
#       ju = sqrt jt
#       jv = integer_pow[ y=2 ] bm
#       jw = reduce_sum[ axes=(0,) ] jv
#       jx = sqrt jw
#       jy = integer_pow[ y=2 ] bo
#       jz = reduce_sum[ axes=(0,) ] jy
#       ka = sqrt jz
#       kb = integer_pow[ y=2 ] bq
#       kc = reduce_sum[ axes=(0,) ] kb
#       kd = sqrt kc
#       ke = integer_pow[ y=2 ] bs
#       kf = reduce_sum[ axes=(0,) ] ke
#       kg = sqrt kf
#       kh = integer_pow[ y=2 ] bu
#       ki = reduce_sum[ axes=(0,) ] kh
#       kj = sqrt ki
#       kk = integer_pow[ y=2 ] bw
#       kl = reduce_sum[ axes=(0,) ] kk
#       km = sqrt kl
#       kn = integer_pow[ y=2 ] by
#       ko = reduce_sum[ axes=(0,) ] kn
#       kp = sqrt ko
#       kq = integer_pow[ y=2 ] ca
#       kr = reduce_sum[ axes=(0,) ] kq
#       ks = sqrt kr
#       kt = integer_pow[ y=2 ] cc
#       ku = reduce_sum[ axes=(0,) ] kt
#       kv = sqrt ku
#       kw = integer_pow[ y=2 ] ce
#       kx = reduce_sum[ axes=(0,) ] kw
#       ky = sqrt kx
#       kz = integer_pow[ y=2 ] cg
#       la = reduce_sum[ axes=(0,) ] kz
#       lb = sqrt la
#       lc = integer_pow[ y=2 ] ci
#       ld = reduce_sum[ axes=(0,) ] lc
#       le = sqrt ld
#       lf = integer_pow[ y=2 ] ck
#       lg = reduce_sum[ axes=(0,) ] lf
#       lh = sqrt lg
#       li = integer_pow[ y=2 ] cm
#       lj = reduce_sum[ axes=(0,) ] li
#       lk = sqrt lj
#       ll = integer_pow[ y=2 ] co
#       lm = reduce_sum[ axes=(0,) ] ll
#       ln = sqrt lm
#       lo = integer_pow[ y=2 ] cq
#       lp = reduce_sum[ axes=(0,) ] lo
#       lq = sqrt lp
#       lr = integer_pow[ y=2 ] cs
#       ls = reduce_sum[ axes=(0,) ] lr
#       lt = sqrt ls
#       lu = integer_pow[ y=2 ] cu
#       lv = reduce_sum[ axes=(0,) ] lu
#       lw = sqrt lv
#       lx = integer_pow[ y=2 ] cw
#       ly = reduce_sum[ axes=(0,) ] lx
#       lz = sqrt ly
#       ma = integer_pow[ y=2 ] cy
#       mb = reduce_sum[ axes=(0,) ] ma
#       mc = sqrt mb
#       md = integer_pow[ y=2 ] da
#       me = reduce_sum[ axes=(0,) ] md
#       mf = sqrt me
#       mg = integer_pow[ y=2 ] dc
#       mh = reduce_sum[ axes=(0,) ] mg
#       mi = sqrt mh
#       mj = integer_pow[ y=2 ] de
#       mk = reduce_sum[ axes=(0,) ] mj
#       ml = sqrt mk
#       mm = integer_pow[ y=2 ] dg
#       mn = reduce_sum[ axes=(0,) ] mm
#       mo = sqrt mn
#       mp = integer_pow[ y=2 ] di
#       mq = reduce_sum[ axes=(0,) ] mp
#       mr = sqrt mq
#       ms = integer_pow[ y=2 ] dk
#       mt = reduce_sum[ axes=(0,) ] ms
#       mu = sqrt mt
#       mv = integer_pow[ y=2 ] dm
#       mw = reduce_sum[ axes=(0,) ] mv
#       mx = sqrt mw
#       my = integer_pow[ y=2 ] do
#       mz = reduce_sum[ axes=(0,) ] my
#       na = sqrt mz
#       nb = integer_pow[ y=2 ] dq
#       nc = reduce_sum[ axes=(0,) ] nb
#       nd = sqrt nc
#       ne = integer_pow[ y=2 ] ds
#       nf = reduce_sum[ axes=(0,) ] ne
#       ng = sqrt nf
#       nh = integer_pow[ y=2 ] du
#       ni = reduce_sum[ axes=(0,) ] nh
#       nj = sqrt ni
#       nk = integer_pow[ y=2 ] dw
#       nl = reduce_sum[ axes=(0,) ] nk
#       nm = sqrt nl
#       nn = integer_pow[ y=2 ] dy
#       no = reduce_sum[ axes=(0,) ] nn
#       np = sqrt no
#       nq = integer_pow[ y=2 ] ea
#       nr = reduce_sum[ axes=(0,) ] nq
#       ns = sqrt nr
#       nt = integer_pow[ y=2 ] ec
#       nu = reduce_sum[ axes=(0,) ] nt
#       nv = sqrt nu
#       nw = integer_pow[ y=2 ] ee
#       nx = reduce_sum[ axes=(0,) ] nw
#       ny = sqrt nx
#       nz = integer_pow[ y=2 ] eg
#       oa = reduce_sum[ axes=(0,) ] nz
#       ob = sqrt oa
#       oc = integer_pow[ y=2 ] ei
#       od = reduce_sum[ axes=(0,) ] oc
#       oe = sqrt od
#       of = integer_pow[ y=2 ] ek
#       og = reduce_sum[ axes=(0,) ] of
#       oh = sqrt og
#       oi = integer_pow[ y=2 ] em
#       oj = reduce_sum[ axes=(0,) ] oi
#       ok = sqrt oj
#       ol = integer_pow[ y=2 ] eo
#       om = reduce_sum[ axes=(0,) ] ol
#       on = sqrt om
#       oo = integer_pow[ y=2 ] eq
#       op = reduce_sum[ axes=(0,) ] oo
#       oq = sqrt op
#       or = integer_pow[ y=2 ] es
#       os = reduce_sum[ axes=(0,) ] or
#       ot = sqrt os
#       ou = integer_pow[ y=2 ] eu
#       ov = reduce_sum[ axes=(0,) ] ou
#       ow = sqrt ov
#       ox = integer_pow[ y=2 ] ew
#       oy = reduce_sum[ axes=(0,) ] ox
#       oz = sqrt oy
#       pa = integer_pow[ y=2 ] ey
#       pb = reduce_sum[ axes=(0,) ] pa
#       pc = sqrt pb
#       pd = integer_pow[ y=2 ] fa
#       pe = reduce_sum[ axes=(0,) ] pd
#       pf = sqrt pe
#       pg = integer_pow[ y=2 ] fc
#       ph = reduce_sum[ axes=(0,) ] pg
#       pi = sqrt ph
#       pj = integer_pow[ y=2 ] fe
#       pk = reduce_sum[ axes=(0,) ] pj
#       pl = sqrt pk
#       pm = integer_pow[ y=2 ] fg
#       pn = reduce_sum[ axes=(0,) ] pm
#       po = sqrt pn
#       pp = integer_pow[ y=2 ] fi
#       pq = reduce_sum[ axes=(0,) ] pp
#       pr = sqrt pq
#       ps = integer_pow[ y=2 ] fk
#       pt = reduce_sum[ axes=(0,) ] ps
#       pu = sqrt pt
#       pv = integer_pow[ y=2 ] fm
#       pw = reduce_sum[ axes=(0,) ] pv
#       px = sqrt pw
#       py = integer_pow[ y=2 ] fo
#       pz = reduce_sum[ axes=(0,) ] py
#       qa = sqrt pz
#       qb = integer_pow[ y=2 ] fq
#       qc = reduce_sum[ axes=(0,) ] qb
#       qd = sqrt qc
#       qe = integer_pow[ y=2 ] fs
#       qf = reduce_sum[ axes=(0,) ] qe
#       qg = sqrt qf
#       qh = integer_pow[ y=2 ] fu
#       qi = reduce_sum[ axes=(0,) ] qh
#       qj = sqrt qi
#       qk = integer_pow[ y=2 ] fw
#       ql = reduce_sum[ axes=(0,) ] qk
#       qm = sqrt ql
#       qn = integer_pow[ y=2 ] fy
#       qo = reduce_sum[ axes=(0,) ] qn
#       qp = sqrt qo
#       qq = integer_pow[ y=2 ] ga
#       qr = reduce_sum[ axes=(0,) ] qq
#       qs = sqrt qr
#       qt = integer_pow[ y=2 ] gc
#       qu = reduce_sum[ axes=(0,) ] qt
#       qv = sqrt qu
#       qw = integer_pow[ y=2 ] ge
#       qx = reduce_sum[ axes=(0,) ] qw
#       qy = sqrt qx
#       qz = integer_pow[ y=2 ] gg
#       ra = reduce_sum[ axes=(0,) ] qz
#       rb = sqrt ra
#       rc = integer_pow[ y=2 ] gi
#       rd = reduce_sum[ axes=(0,) ] rc
#       re = sqrt rd
#       rf = integer_pow[ y=2 ] gk
#       rg = reduce_sum[ axes=(0,) ] rf
#       rh = sqrt rg
#       ri = integer_pow[ y=2 ] gm
#       rj = reduce_sum[ axes=(0,) ] ri
#       rk = sqrt rj
#       rl = integer_pow[ y=2 ] go
#       rm = reduce_sum[ axes=(0,) ] rl
#       rn = sqrt rm
#       ro = integer_pow[ y=2 ] gq
#       rp = reduce_sum[ axes=(0,) ] ro
#       rq = sqrt rp
#       rr = integer_pow[ y=2 ] gs
#       rs = reduce_sum[ axes=(0,) ] rr
#       rt = sqrt rs
#       ru = integer_pow[ y=2 ] gu
#       rv = reduce_sum[ axes=(0,) ] ru
#       rw = sqrt rv
#       rx = integer_pow[ y=2 ] gw
#       ry = reduce_sum[ axes=(0,) ] rx
#       rz = sqrt ry
#       sa = integer_pow[ y=2 ] gy
#       sb = reduce_sum[ axes=(0,) ] sa
#       sc = sqrt sb
#       sd = integer_pow[ y=2 ] ha
#       se = reduce_sum[ axes=(0,) ] sd
#       sf = sqrt se
#       sg = integer_pow[ y=2 ] hc
#       sh = reduce_sum[ axes=(0,) ] sg
#       si = sqrt sh
#       sj = integer_pow[ y=2 ] he
#       sk = reduce_sum[ axes=(0,) ] sj
#       sl = sqrt sk
#       sm = integer_pow[ y=2 ] hg
#       sn = reduce_sum[ axes=(0,) ] sm
#       so = sqrt sn
#       sp = integer_pow[ y=2 ] hi
#       sq = reduce_sum[ axes=(0,) ] sp
#       sr = sqrt sq
#       ss = integer_pow[ y=2 ] hk
#       st = reduce_sum[ axes=(0,) ] ss
#       su = sqrt st
#       sv = integer_pow[ y=2 ] hm
#       sw = reduce_sum[ axes=(0,) ] sv
#       sx = sqrt sw
#       sy = integer_pow[ y=2 ] ho
#       sz = reduce_sum[ axes=(0,) ] sy
#       ta = sqrt sz
#       tb = integer_pow[ y=2 ] hq
#       tc = reduce_sum[ axes=(0,) ] tb
#       td = sqrt tc
#       te = integer_pow[ y=2 ] hs
#       tf = reduce_sum[ axes=(0,) ] te
#       tg = sqrt tf
#       th = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] hv
#       ti = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] hy
#       tj = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ib
#       tk = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ie
#       tl = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ih
#       tm = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ik
#       tn = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] in
#       to = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] iq
#       tp = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] it
#       tq = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] iw
#       tr = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] iz
#       ts = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] jc
#       tt = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] jf
#       tu = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ji
#       tv = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] jl
#       tw = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] jo
#       tx = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] jr
#       ty = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ju
#       tz = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] jx
#       ua = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ka
#       ub = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] kd
#       uc = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] kg
#       ud = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] kj
#       ue = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] km
#       uf = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] kp
#       ug = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ks
#       uh = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] kv
#       ui = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ky
#       uj = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] lb
#       uk = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] le
#       ul = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] lh
#       um = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] lk
#       un = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ln
#       uo = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] lq
#       up = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] lt
#       uq = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] lw
#       ur = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] lz
#       us = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] mc
#       ut = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] mf
#       uu = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] mi
#       uv = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ml
#       uw = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] mo
#       ux = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] mr
#       uy = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] mu
#       uz = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] mx
#       va = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] na
#       vb = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] nd
#       vc = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ng
#       vd = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] nj
#       ve = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] nm
#       vf = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] np
#       vg = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ns
#       vh = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] nv
#       vi = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ny
#       vj = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ob
#       vk = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] oe
#       vl = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] oh
#       vm = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ok
#       vn = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] on
#       vo = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] oq
#       vp = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ot
#       vq = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ow
#       vr = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] oz
#       vs = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] pc
#       vt = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] pf
#       vu = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] pi
#       vv = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] pl
#       vw = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] po
#       vx = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] pr
#       vy = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] pu
#       vz = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] px
#       wa = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] qa
#       wb = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] qd
#       wc = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] qg
#       wd = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] qj
#       we = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] qm
#       wf = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] qp
#       wg = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] qs
#       wh = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] qv
#       wi = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] qy
#       wj = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] rb
#       wk = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] re
#       wl = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] rh
#       wm = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] rk
#       wn = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] rn
#       wo = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] rq
#       wp = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] rt
#       wq = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] rw
#       wr = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] rz
#       ws = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] sc
#       wt = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] sf
#       wu = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] si
#       wv = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] sl
#       ww = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] so
#       wx = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] sr
#       wy = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] su
#       wz = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] sx
#       xa = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] ta
#       xb = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] td
#       xc = broadcast_in_dim[ broadcast_dimensions=(  )
#                              shape=(1,) ] tg
#       xd = concatenate[ dimension=0 ] th ti tj tk tl tm tn to tp tq tr ts tt tu tv tw
#       xe = concatenate[ dimension=0 ] tx ty tz ua ub uc ud ue uf ug uh ui uj uk ul um
#       xf = concatenate[ dimension=0 ] un uo up uq ur us ut uu uv uw ux uy uz va vb vc
#       xg = concatenate[ dimension=0 ] vd ve vf vg vh vi vj vk vl vm vn vo vp vq vr vs
#       xh = concatenate[ dimension=0 ] vt vu vv vw vx vy vz wa wb wc wd we wf wg wh wi
#       xi = concatenate[ dimension=0 ] wj wk wl wm wn wo wp wq wr ws wt wu wv ww wx wy
#       xj = concatenate[ dimension=0 ] wz xa xb xc
#       xk = concatenate[ dimension=0 ] xd xe xf xg xh xi xj
#   in (xk,) }

# %%
jax.make_jaxpr(vmap_norm)(matrix)
# Out:
# { lambda  ; a.
#   let b = integer_pow[ y=2 ] a
#       c = reduce_sum[ axes=(1,) ] b
#       d = sqrt c
#   in (d,) }

# %%
global_list = []

@jit
def norm(vect):
    global_list.append(vect)
    return jnp.sqrt(jnp.sum(vect ** 2))

norm(x)
norm(x)
norm(x)

print(len(global_list))
# Out:
# 1

# %%
jax.make_jaxpr(norm)(x)
# Out:
# { lambda  ; a.
#   let b = xla_call[ backend=None
#                     call_jaxpr={ lambda  ; a.
#                                  let b = integer_pow[ y=2 ] a
#                                      c = reduce_sum[ axes=(0,) ] b
#                                      d = sqrt c
#                                  in (d,) }
#                     device=None
#                     donated_invars=(False,)
#                     name=norm ] a
#   in (b,) }
